# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Scripts/.' .

# %%
# !unzip -q '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Data/train_images320x480.zip'

# %% [markdown]
# ### Dependencies

# %%
# !pip install efficientnet

# %%
from utillity_script_cloud_segmentation import *
import efficientnet.keras as efn
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.

# %%
seed = 0
seed_everything(seed)
warnings.filterwarnings("ignore")

# %%
base_path = '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/'
data_path = base_path + 'Data/'
model_base_path = base_path + 'Models/files/classification/'
train_path = data_path + 'train.csv'
hold_out_set_path = data_path + 'hold-out.csv'
train_images_dest_path = 'train_images/'

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv(train_path)
hold_out_set = pd.read_csv(hold_out_set_path)

X_train = hold_out_set[hold_out_set['set'] == 'train']
X_val = hold_out_set[hold_out_set['set'] == 'validation']

print('Compete set samples:', len(train))
print('Train samples: ', len(X_train))
print('Validation samples: ', len(X_val))

# Preprocecss data
train['image'] = train['Image_Label'].apply(lambda x: x.split('_')[0])
label_columns=['Fish', 'Flower', 'Gravel', 'Sugar']
for label in label_columns:
  X_train[label].replace({0: 1, 1: 0}, inplace=True)
  X_val[label].replace({0: 1, 1: 0}, inplace=True)

display(X_train.head())
# Out:
# Compete set samples: 22184
# Train samples:  4420
# Validation samples:  1105
#          image                                          Fish_mask  ... Sugar    set
# 0  66cda54.jpg                                                NaN  ...     0  train
# 1  61d6640.jpg                                                NaN  ...     0  train
# 2  bb31239.jpg  29 604 1429 604 2829 604 4229 604 5629 604 702...  ...     1  train
# 3  74d06fc.jpg                                                NaN  ...     1  train
# 4  f13cbe0.jpg  330457 1020 331857 1020 333257 1020 334657 102...  ...     0  train
#
# [5 rows x 10 columns]

# %% [markdown]
# # Model parameters

# %%
BATCH_SIZE = 64
EPOCHS = 30
LEARNING_RATE = 1e-4
HEIGHT = 224
WIDTH = 224
CHANNELS = 3
N_CLASSES = 4
ES_PATIENCE = 5
RLROP_PATIENCE = 2
DECAY_DROP = 0.2

model_name = '14-EfficientNetB0_%sx%s_untrained' % (HEIGHT, WIDTH)
model_path = model_base_path + '%s.h5' % (model_name)

# %% [markdown]
# ### Data generator

# %%
datagen=ImageDataGenerator(rescale=1./255.,
                           vertical_flip=True,
                           horizontal_flip=True,
                           zoom_range=[1, 1.2],
                           fill_mode='constant',
                           cval=0.)

test_datagen=ImageDataGenerator(rescale=1./255.)

train_generator=datagen.flow_from_dataframe(
                        dataframe=X_train,
                        directory=train_images_dest_path,
                        x_col="image",
                        y_col=label_columns,
                        target_size=(HEIGHT, WIDTH),
                        batch_size=BATCH_SIZE,
                        class_mode="other",
                        shuffle=True,
                        seed=seed)

valid_generator=test_datagen.flow_from_dataframe(
                             dataframe=X_val,
                             directory=train_images_dest_path,
                             x_col="image",
                             y_col=label_columns,
                             target_size=(HEIGHT, WIDTH),
                             batch_size=BATCH_SIZE,
                             class_mode="other",
                             shuffle=True,
                             seed=seed)
# Out:
# Found 4420 validated image filenames.
# Found 1105 validated image filenames.

# %% [markdown]
# # Model

# %%
def create_model(input_shape, N_CLASSES):
    input_tensor = Input(shape=input_shape)
    base_model = efn.EfficientNetB0(weights=None, 
                                    include_top=False,
                                    input_tensor=input_tensor, 
                                    pooling='avg')

    x = base_model.output
    final_output = Dense(N_CLASSES, activation='sigmoid')(x)
    model = Model(input_tensor, final_output)
    
    return model

# %%
model = create_model((None, None, CHANNELS), N_CLASSES)

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', save_best_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, verbose=1)

metric_list = ['accuracy']
callback_list = [checkpoint, es, rlrop]

# %% [markdown]
# ## Fine-tune all layers

# %%
for layer in model.layers:
  layer.trainable = True

optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.99, nesterov=True)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=metric_list)
# model.summary()

# %%
STEP_SIZE_TRAIN = len(X_train)//BATCH_SIZE
STEP_SIZE_VALID = len(X_val)//BATCH_SIZE

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator,
                              validation_steps=STEP_SIZE_VALID,
                              callbacks=callback_list,
                              epochs=EPOCHS,
                              verbose=1).history
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/30
# 69/69 [==============================] - 110s 2s/step - loss: 0.7059 - acc: 0.5269 - val_loss: 0.7694 - val_acc: 0.5427
# Epoch 2/30
# 69/69 [==============================] - 92s 1s/step - loss: 0.6860 - acc: 0.5546 - val_loss: 1.0891 - val_acc: 0.5072
# Epoch 3/30
# 69/69 [==============================] - 92s 1s/step - loss: 0.6780 - acc: 0.5718 - val_loss: 0.9265 - val_acc: 0.5586
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 4/30
# 69/69 [==============================] - 92s 1s/step - loss: 0.6810 - acc: 0.5629 - val_loss: 0.8862 - val_acc: 0.5569
# Epoch 5/30
# 69/69 [==============================] - 93s 1s/step - loss: 0.6823 - acc: 0.5745 - val_loss: 0.7704 - val_acc: 0.5555
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# Epoch 6/30
# 69/69 [==============================] - 96s 1s/step - loss: 0.6762 - acc: 0.5770 - val_loss: 0.7208 - val_acc: 0.5605
# Epoch 7/30
# 69/69 [==============================] - 94s 1s/step - loss: 0.6728 - acc: 0.5783 - val_loss: 0.7094 - val_acc: 0.5672
# Epoch 8/30
# 69/69 [==============================] - 92s 1s/step - loss: 0.6740 - acc: 0.5732 - val_loss: 0.7097 - val_acc: 0.5567
# Epoch 9/30
# 69/69 [==============================] - 91s 1s/step - loss: 0.6737 - acc: 0.5783 - val_loss: 0.7165 - val_acc: 0.5557
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# Epoch 10/30
# 69/69 [==============================] - 90s 1s/step - loss: 0.6735 - acc: 0.5766 - val_loss: 0.7049 - val_acc: 0.5572
# Epoch 11/30
# 69/69 [==============================] - 90s 1s/step - loss: 0.6766 - acc: 0.5715 - val_loss: 0.7181 - val_acc: 0.5569
# Epoch 12/30
# 69/69 [==============================] - 90s 1s/step - loss: 0.6755 - acc: 0.5702 - val_loss: 0.7182 - val_acc: 0.5509
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# Epoch 13/30
# 69/69 [==============================] - 90s 1s/step - loss: 0.6723 - acc: 0.5713 - val_loss: 0.7093 - val_acc: 0.5588
# Epoch 14/30
# 69/69 [==============================] - 92s 1s/step - loss: 0.6737 - acc: 0.5752 - val_loss: 0.7075 - val_acc: 0.5591
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# Epoch 15/30
# 69/69 [==============================] - 92s 1s/step - loss: 0.6711 - acc: 0.5774 - val_loss: 0.7114 - val_acc: 0.5593
# Restoring model weights from the end of the best epoch
# Epoch 00015: early stopping

# %% [markdown]
# ## Model loss graph

# %%
#@title
plot_metrics(history, metric_list=['loss', 'acc'])

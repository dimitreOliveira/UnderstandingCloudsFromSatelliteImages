# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Scripts/.' .

# %%
# !unzip -q '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Data/train_images320x480.zip'

# %% [markdown]
# ### Dependencies

# %%
from utillity_script_cloud_segmentation import *
from utillity_script_lr_schedulers2 import *
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.

# %%
seed = 0
seed_everything(seed)
warnings.filterwarnings("ignore")
# Out:
# WARNING:tensorflow:From /content/utillity_script_cloud_segmentation.py:47: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.

# %%
base_path = '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/'
data_path = base_path + 'Data/'
model_base_path = base_path + 'Models/files/classification/'
train_path = data_path + 'train.csv'
hold_out_set_path = data_path + 'hold-out.csv'
train_images_dest_path = 'train_images/'

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv(train_path)
hold_out_set = pd.read_csv(hold_out_set_path)

X_train = hold_out_set[hold_out_set['set'] == 'train']
X_val = hold_out_set[hold_out_set['set'] == 'validation']

print('Compete set samples:', len(train))
print('Train samples: ', len(X_train))
print('Validation samples: ', len(X_val))

# Preprocecss data
train['image'] = train['Image_Label'].apply(lambda x: x.split('_')[0])
label_columns=['Fish', 'Flower', 'Gravel', 'Sugar']
for label in label_columns:
  X_train[label].replace({0: 1, 1: 0}, inplace=True)
  X_val[label].replace({0: 1, 1: 0}, inplace=True)

display(X_train.head())
# Out:
# Compete set samples: 22184
# Train samples:  4420
# Validation samples:  1105
#          image                                          Fish_mask  ... Sugar    set
# 0  1f3d231.jpg                                                NaN  ...     1  train
# 1  0fa3287.jpg                                                NaN  ...     0  train
# 2  4d17338.jpg  64 1141 1464 1141 2864 1141 4264 1141 5664 114...  ...     0  train
# 3  12e55a8.jpg                                                NaN  ...     0  train
# 4  697eb53.jpg  52180 1006 53580 1006 54980 1006 56380 1006 57...  ...     1  train
#
# [5 rows x 10 columns]

# %% [markdown]
# # Model parameters

# %%
BATCH_SIZE = 64
WARMUP_EPOCHS = 3
WARMUP_LEARNING_RATE = 1e-3
EPOCHS = 30
BASE_LEARNING_RATE = 10**(-5.6)
LEARNING_RATE = 10**(-1.7)
HEIGHT = 224
WIDTH = 224
CHANNELS = 3
N_CLASSES = 4
ES_PATIENCE = 10
STEP_SIZE_TRAIN = len(X_train)//BATCH_SIZE
STEP_SIZE_VALID = len(X_val)//BATCH_SIZE
CYCLE_SIZE = 6
STEP_SIZE = (CYCLE_SIZE // 2) * STEP_SIZE_TRAIN

model_name = '26-EfficientNetB0_%sx%s' % (HEIGHT, WIDTH)
model_path = model_base_path + '%s.h5' % (model_name)

# %% [markdown]
# ### Data generator

# %%
datagen=ImageDataGenerator(rescale=1./255.,
                           vertical_flip=True,
                           horizontal_flip=True,
                           zoom_range=[1, 1.1],
                           shear_range=45.0,
                           rotation_range=360,
                           width_shift_range=0.1,
                           height_shift_range=0.1,
                           brightness_range=(0.9, 1),
                           fill_mode='constant',
                           cval=0.)

test_datagen=ImageDataGenerator(rescale=1./255.)

train_generator=datagen.flow_from_dataframe(
                        dataframe=X_train,
                        directory=train_images_dest_path,
                        x_col="image",
                        y_col=label_columns,
                        target_size=(HEIGHT, WIDTH),
                        batch_size=BATCH_SIZE,
                        class_mode="other",
                        shuffle=True,
                        seed=seed)

valid_generator=test_datagen.flow_from_dataframe(
                             dataframe=X_val,
                             directory=train_images_dest_path,
                             x_col="image",
                             y_col=label_columns,
                             target_size=(HEIGHT, WIDTH),
                             batch_size=BATCH_SIZE,
                             class_mode="other",
                             shuffle=True,
                             seed=seed)
# Out:
# Found 4420 validated image filenames.
# Found 1105 validated image filenames.

# %% [markdown]
# # Model

# %%
def create_model(input_shape, N_CLASSES):
    input_tensor = Input(shape=input_shape)
    base_model = efn.EfficientNetB0(weights='imagenet', 
                                    include_top=False,
                                    input_tensor=input_tensor, 
                                    pooling='avg')

    x = base_model.output
    final_output = Dense(N_CLASSES, activation='sigmoid')(x)
    model = Model(input_tensor, final_output)
    
    return model

# %% [markdown]
# ## Warmup top layers

# %%
model = create_model((None, None, CHANNELS), N_CLASSES)
metric_list = ['accuracy']

freeze_segmentation_model(model)
model.layers[-1].trainable = True

optimizer = optimizers.SGD(lr=WARMUP_LEARNING_RATE, momentum=0.9, nesterov=True)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=metric_list)

# %%
warmup_history = model.fit_generator(generator=train_generator,
                                      steps_per_epoch=STEP_SIZE_TRAIN,
                                      validation_data=valid_generator,
                                      validation_steps=STEP_SIZE_VALID,
                                      epochs=WARMUP_EPOCHS,
                                      verbose=1).history
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/3
# 69/69 [==============================] - 89s 1s/step - loss: 0.7011 - acc: 0.5229 - val_loss: 0.6891 - val_acc: 0.5506
# Epoch 2/3
# 69/69 [==============================] - 76s 1s/step - loss: 0.6844 - acc: 0.5641 - val_loss: 0.6850 - val_acc: 0.5641
# Epoch 3/3
# 69/69 [==============================] - 76s 1s/step - loss: 0.6811 - acc: 0.5742 - val_loss: 0.6775 - val_acc: 0.5778

# %%
for layer in model.layers:
    layer.trainable = True
    
warm_weights = model.get_weights()

# %% [markdown]
# # Learning rate finder

# %%
#@title
# #@title
lr_finder = LRFinder(num_samples=len(X_train), batch_size=BATCH_SIZE, minimum_lr=1e-6, maximum_lr=10, verbose=0)

optimizer = optimizers.SGD(lr=WARMUP_LEARNING_RATE, momentum=0.9, nesterov=True)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit_generator(generator=train_generator, 
                              steps_per_epoch=STEP_SIZE_TRAIN, 
                              epochs=1, 
                              callbacks=[lr_finder])

plt.rcParams.update({'font.size': 16})
plt.figure(figsize=(24, 8))
plt.axvline(x=np.log10(BASE_LEARNING_RATE), color='green')
plt.axvline(x=np.log10(LEARNING_RATE), color='red')
lr_finder.plot_schedule(clip_beginning=2)
# Out:
# Epoch 1/1
# 69/69 [==============================] - 81s 1s/step - loss: 0.7978

# %% [markdown]
# ## Fine-tune all layers

# %%
model.set_weights(warm_weights)

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', save_best_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
cyclicalLR = CyclicLR(base_lr=BASE_LEARNING_RATE, max_lr=LEARNING_RATE, step_size=STEP_SIZE, mode='triangular')

callback_list = [checkpoint, es, cyclicalLR]

optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.9, nesterov=True)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=metric_list)

# %%
history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator,
                              validation_steps=STEP_SIZE_VALID,
                              callbacks=callback_list,
                              epochs=EPOCHS,
                              verbose=2).history
# Out:
# Epoch 1/30
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.865581). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
#  - 87s - loss: 0.6684 - acc: 0.5904 - val_loss: 0.6765 - val_acc: 0.5813
# Epoch 2/30
#  - 79s - loss: 0.6207 - acc: 0.6536 - val_loss: 0.6154 - val_acc: 0.6595
# Epoch 3/30
#  - 78s - loss: 0.5785 - acc: 0.6898 - val_loss: 0.6165 - val_acc: 0.6635
# Epoch 4/30
#  - 78s - loss: 0.5547 - acc: 0.7106 - val_loss: 0.5615 - val_acc: 0.7116
# Epoch 5/30
#  - 77s - loss: 0.5428 - acc: 0.7194 - val_loss: 0.5576 - val_acc: 0.7111
# Epoch 6/30
#  - 77s - loss: 0.5406 - acc: 0.7223 - val_loss: 0.5490 - val_acc: 0.7171
# Epoch 7/30
#  - 76s - loss: 0.5323 - acc: 0.7321 - val_loss: 0.5492 - val_acc: 0.7087
# Epoch 8/30
#  - 76s - loss: 0.5324 - acc: 0.7260 - val_loss: 0.5744 - val_acc: 0.7070
# Epoch 9/30
#  - 77s - loss: 0.5262 - acc: 0.7341 - val_loss: 0.5621 - val_acc: 0.6996
# Epoch 10/30
#  - 76s - loss: 0.5227 - acc: 0.7403 - val_loss: 0.5426 - val_acc: 0.7188
# Epoch 11/30
#  - 76s - loss: 0.5165 - acc: 0.7357 - val_loss: 0.5597 - val_acc: 0.7058
# Epoch 12/30
#  - 77s - loss: 0.5110 - acc: 0.7418 - val_loss: 0.5482 - val_acc: 0.7082
# Epoch 13/30
#  - 75s - loss: 0.5091 - acc: 0.7437 - val_loss: 0.5488 - val_acc: 0.7092
# Epoch 14/30
#  - 78s - loss: 0.5067 - acc: 0.7403 - val_loss: 0.5189 - val_acc: 0.7366
# Epoch 15/30
#  - 75s - loss: 0.5063 - acc: 0.7500 - val_loss: 0.5219 - val_acc: 0.7315
# Epoch 16/30
#  - 76s - loss: 0.5027 - acc: 0.7468 - val_loss: 0.5239 - val_acc: 0.7217
# Epoch 17/30
#  - 77s - loss: 0.4938 - acc: 0.7524 - val_loss: 0.5332 - val_acc: 0.7243
# Epoch 18/30
#  - 75s - loss: 0.4982 - acc: 0.7529 - val_loss: 0.5348 - val_acc: 0.7214
# Epoch 19/30
#  - 76s - loss: 0.4919 - acc: 0.7559 - val_loss: 0.5406 - val_acc: 0.7167
# Epoch 20/30
#  - 79s - loss: 0.4929 - acc: 0.7554 - val_loss: 0.5542 - val_acc: 0.7077
# Epoch 21/30
#  - 77s - loss: 0.4893 - acc: 0.7570 - val_loss: 0.5251 - val_acc: 0.7308
# Epoch 22/30
#  - 76s - loss: 0.4898 - acc: 0.7556 - val_loss: 0.5584 - val_acc: 0.7061
# Epoch 23/30
#  - 75s - loss: 0.4843 - acc: 0.7584 - val_loss: 0.5110 - val_acc: 0.7368
# Epoch 24/30
#  - 76s - loss: 0.4835 - acc: 0.7560 - val_loss: 0.5348 - val_acc: 0.7255
# Epoch 25/30
#  - 76s - loss: 0.4821 - acc: 0.7612 - val_loss: 0.5300 - val_acc: 0.7322
# Epoch 26/30
#  - 76s - loss: 0.4811 - acc: 0.7611 - val_loss: 0.5389 - val_acc: 0.7241
# Epoch 27/30
#  - 76s - loss: 0.4764 - acc: 0.7664 - val_loss: 0.5402 - val_acc: 0.7245
# Epoch 28/30
#  - 76s - loss: 0.4823 - acc: 0.7653 - val_loss: 0.5878 - val_acc: 0.6943
# Epoch 29/30
#  - 76s - loss: 0.4776 - acc: 0.7648 - val_loss: 0.5716 - val_acc: 0.7075
# Epoch 30/30
#  - 76s - loss: 0.4733 - acc: 0.7664 - val_loss: 0.5311 - val_acc: 0.7255

# %% [markdown]
# ## Model loss graph

# %%
#@title
metrics_history = ['loss', 'acc']
for metric_hist in metrics_history:
  history[metric_hist] = warmup_history[metric_hist] + history[metric_hist]
  history['val_' + metric_hist] = warmup_history['val_' + metric_hist] + history['val_' + metric_hist]

plot_metrics(history, metric_list=metrics_history)

# %% [markdown]
# ## Scheduler learning rates

# %%
#@title
fig, ax1 = plt.subplots(1, 1, figsize=(20, 6))

plt.xlabel('Training Iterations')
plt.ylabel('Learning Rate')
plt.plot(cyclicalLR.history['lr'])
plt.show()

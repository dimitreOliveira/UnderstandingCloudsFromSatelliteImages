# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Scripts/.' .

# %%
# !unzip -q '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Data/train_images320x480.zip'

# %% [markdown]
# ### Dependencies

# %%
from utillity_script_cloud_segmentation import *
from utillity_script_lr_schedulers2 import *
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.

# %%
seed = 0
seed_everything(seed)
warnings.filterwarnings("ignore")
# Out:
# WARNING:tensorflow:From /content/utillity_script_cloud_segmentation.py:47: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.

# %%
base_path = '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/'
data_path = base_path + 'Data/'
model_base_path = base_path + 'Models/files/classification/'
train_path = data_path + 'train.csv'
hold_out_set_path = data_path + 'hold-out.csv'
train_images_dest_path = 'train_images/'

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv(train_path)
hold_out_set = pd.read_csv(hold_out_set_path)

X_train = hold_out_set[hold_out_set['set'] == 'train']
X_val = hold_out_set[hold_out_set['set'] == 'validation']

print('Compete set samples:', len(train))
print('Train samples: ', len(X_train))
print('Validation samples: ', len(X_val))

# Preprocecss data
train['image'] = train['Image_Label'].apply(lambda x: x.split('_')[0])
label_columns=['Fish', 'Flower', 'Gravel', 'Sugar']
for label in label_columns:
  X_train[label].replace({0: 1, 1: 0}, inplace=True)
  X_val[label].replace({0: 1, 1: 0}, inplace=True)

display(X_train.head())
# Out:
# Compete set samples: 22184
# Train samples:  4420
# Validation samples:  1105
#          image                                          Fish_mask  ... Sugar    set
# 0  1f3d231.jpg                                                NaN  ...     1  train
# 1  0fa3287.jpg                                                NaN  ...     0  train
# 2  4d17338.jpg  64 1141 1464 1141 2864 1141 4264 1141 5664 114...  ...     0  train
# 3  12e55a8.jpg                                                NaN  ...     0  train
# 4  697eb53.jpg  52180 1006 53580 1006 54980 1006 56380 1006 57...  ...     1  train
#
# [5 rows x 10 columns]

# %% [markdown]
# # Model parameters

# %%
BATCH_SIZE = 64
WARMUP_EPOCHS = 3
WARMUP_LEARNING_RATE = 1e-3
EPOCHS = 20
LEARNING_RATE = 10**(-1.5)
HEIGHT = 224
WIDTH = 224
CHANNELS = 3
N_CLASSES = 4
ES_PATIENCE = 10
STEP_SIZE_TRAIN = len(X_train)//BATCH_SIZE
STEP_SIZE_VALID = len(X_val)//BATCH_SIZE

model_name = '27-EfficientNetB0_%sx%s' % (HEIGHT, WIDTH)
model_path = model_base_path + '%s.h5' % (model_name)

# %% [markdown]
# ### Data generator

# %%
datagen=ImageDataGenerator(rescale=1./255.,
                           vertical_flip=True,
                           horizontal_flip=True,
                           zoom_range=[1, 1.1],
                           shear_range=45.0,
                           rotation_range=360,
                           width_shift_range=0.1,
                           height_shift_range=0.1,
                           brightness_range=(0.9, 1),
                           fill_mode='constant',
                           cval=0.)

test_datagen=ImageDataGenerator(rescale=1./255.)

train_generator=datagen.flow_from_dataframe(
                        dataframe=X_train,
                        directory=train_images_dest_path,
                        x_col="image",
                        y_col=label_columns,
                        target_size=(HEIGHT, WIDTH),
                        batch_size=BATCH_SIZE,
                        class_mode="other",
                        shuffle=True,
                        seed=seed)

valid_generator=test_datagen.flow_from_dataframe(
                             dataframe=X_val,
                             directory=train_images_dest_path,
                             x_col="image",
                             y_col=label_columns,
                             target_size=(HEIGHT, WIDTH),
                             batch_size=BATCH_SIZE,
                             class_mode="other",
                             shuffle=True,
                             seed=seed)
# Out:
# Found 4420 validated image filenames.
# Found 1105 validated image filenames.
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:656: DeprecationWarning: `class_mode` "other" is deprecated, please use `class_mode` "raw".
#   '`class_mode` "raw".', DeprecationWarning)

# %% [markdown]
# # Model

# %%
def create_model(input_shape, N_CLASSES):
    input_tensor = Input(shape=input_shape)
    base_model = efn.EfficientNetB0(weights='imagenet', 
                                    include_top=False,
                                    input_tensor=input_tensor, 
                                    pooling='avg')

    x = base_model.output
    final_output = Dense(N_CLASSES, activation='sigmoid')(x)
    model = Model(input_tensor, final_output)
    
    return model

# %% [markdown]
# ## Warmup top layers

# %%
model = create_model((None, None, CHANNELS), N_CLASSES)
metric_list = ['accuracy']

freeze_segmentation_model(model)
model.layers[-1].trainable = True

optimizer = optimizers.SGD(lr=WARMUP_LEARNING_RATE, momentum=0.9, nesterov=True)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=metric_list)

# %%
warmup_history = model.fit_generator(generator=train_generator,
                                      steps_per_epoch=STEP_SIZE_TRAIN,
                                      validation_data=valid_generator,
                                      validation_steps=STEP_SIZE_VALID,
                                      epochs=WARMUP_EPOCHS,
                                      verbose=1).history
# Out:
# Epoch 1/3
# 69/69 [==============================] - 101s 1s/step - loss: 0.6853 - acc: 0.5563 - val_loss: 0.6774 - val_acc: 0.5749
# Epoch 2/3
# 69/69 [==============================] - 92s 1s/step - loss: 0.6805 - acc: 0.5693 - val_loss: 0.6733 - val_acc: 0.5836
# Epoch 3/3
# 69/69 [==============================] - 92s 1s/step - loss: 0.6721 - acc: 0.5838 - val_loss: 0.6709 - val_acc: 0.5896

# %%
for layer in model.layers:
    layer.trainable = True
    
warm_weights = model.get_weights()

# %% [markdown]
# # Learning rate finder

# %%
#@title
lr_finder = LRFinder(num_samples=len(X_train), batch_size=BATCH_SIZE, minimum_lr=1e-6, maximum_lr=10, verbose=0)

optimizer = optimizers.SGD(lr=WARMUP_LEARNING_RATE, momentum=0.9, nesterov=True)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit_generator(generator=train_generator, 
                              steps_per_epoch=STEP_SIZE_TRAIN, 
                              epochs=1, 
                              callbacks=[lr_finder])

plt.rcParams.update({'font.size': 16})
plt.figure(figsize=(24, 8))
plt.axvline(x=np.log10(LEARNING_RATE), color='red')
lr_finder.plot_schedule(clip_beginning=5)

# %% [markdown]
# ## Fine-tune all layers

# %%
model.set_weights(warm_weights)

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', save_best_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
oneCycleLR = OneCycleLR(max_lr=LEARNING_RATE, maximum_momentum=0.95, minimum_momentum=0.85, 
                        epochs=EPOCHS, batch_size=BATCH_SIZE, samples=len(X_train), steps=STEP_SIZE_TRAIN)

callback_list = [checkpoint, es, oneCycleLR]

optimizer = optimizers.SGD(lr=LEARNING_RATE, momentum=0.9, nesterov=True)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=metric_list)

# %%
history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator,
                              validation_steps=STEP_SIZE_VALID,
                              callbacks=callback_list,
                              epochs=EPOCHS,
                              verbose=2).history
# Out:
# Epoch 1/20
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (1.224907). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
#  - 111s - loss: 0.6548 - acc: 0.6158 - val_loss: 0.6381 - val_acc: 0.6480
#  - lr: 0.00628 - momentum: 0.94
# Epoch 2/20
#  - 101s - loss: 0.6002 - acc: 0.6744 - val_loss: 0.5981 - val_acc: 0.6760
#  - lr: 0.00944 - momentum: 0.93
# Epoch 3/20
#  - 101s - loss: 0.5709 - acc: 0.6995 - val_loss: 0.5676 - val_acc: 0.7065
#  - lr: 0.01260 - momentum: 0.92
# Epoch 4/20
#  - 101s - loss: 0.5570 - acc: 0.7093 - val_loss: 0.5764 - val_acc: 0.7020
#  - lr: 0.01577 - momentum: 0.91
# Epoch 5/20
#  - 101s - loss: 0.5432 - acc: 0.7185 - val_loss: 0.5656 - val_acc: 0.7051
#  - lr: 0.01893 - momentum: 0.89
# Epoch 6/20
#  - 101s - loss: 0.5328 - acc: 0.7242 - val_loss: 0.5391 - val_acc: 0.7183
#  - lr: 0.02209 - momentum: 0.88
# Epoch 7/20
#  - 100s - loss: 0.5291 - acc: 0.7277 - val_loss: 0.6083 - val_acc: 0.7169
#  - lr: 0.02525 - momentum: 0.87
# Epoch 8/20
#  - 100s - loss: 0.5177 - acc: 0.7392 - val_loss: 0.5898 - val_acc: 0.7037
#  - lr: 0.02841 - momentum: 0.86
# Epoch 9/20
#  - 99s - loss: 0.5134 - acc: 0.7417 - val_loss: 0.5213 - val_acc: 0.7394
#  - lr: 0.03158 - momentum: 0.85
# Epoch 10/20
#  - 98s - loss: 0.5066 - acc: 0.7462 - val_loss: 0.5420 - val_acc: 0.7190
#  - lr: 0.02851 - momentum: 0.86
# Epoch 11/20
#  - 99s - loss: 0.4978 - acc: 0.7505 - val_loss: 0.5398 - val_acc: 0.7161
#  - lr: 0.02534 - momentum: 0.87
# Epoch 12/20
#  - 99s - loss: 0.4997 - acc: 0.7482 - val_loss: 0.5435 - val_acc: 0.7113
#  - lr: 0.02218 - momentum: 0.88
# Epoch 13/20
#  - 100s - loss: 0.4914 - acc: 0.7529 - val_loss: 0.6302 - val_acc: 0.6792
#  - lr: 0.01902 - momentum: 0.89
# Epoch 14/20
#  - 98s - loss: 0.4973 - acc: 0.7525 - val_loss: 0.5664 - val_acc: 0.7032
#  - lr: 0.01586 - momentum: 0.91
# Epoch 15/20
#  - 101s - loss: 0.4885 - acc: 0.7579 - val_loss: 0.5436 - val_acc: 0.7188
#  - lr: 0.01269 - momentum: 0.92
# Epoch 16/20
#  - 99s - loss: 0.4821 - acc: 0.7627 - val_loss: 0.5441 - val_acc: 0.7231
#  - lr: 0.00953 - momentum: 0.93
# Epoch 17/20
#  - 100s - loss: 0.4904 - acc: 0.7523 - val_loss: 0.5329 - val_acc: 0.7253
#  - lr: 0.00637 - momentum: 0.94
# Epoch 18/20
#  - 99s - loss: 0.4794 - acc: 0.7621 - val_loss: 0.5512 - val_acc: 0.7123
#  - lr: 0.00321 - momentum: 0.95
# Epoch 19/20
#  - 100s - loss: 0.4819 - acc: 0.7602 - val_loss: 0.5553 - val_acc: 0.7100
# Restoring model weights from the end of the best epoch
#  - lr: 0.00162 - momentum: 0.95
# Epoch 00019: early stopping

# %% [markdown]
# ## Model loss graph

# %%
#@title
metrics_history = ['loss', 'acc']
for metric_hist in metrics_history:
  history[metric_hist] = warmup_history[metric_hist] + history[metric_hist]
  history['val_' + metric_hist] = warmup_history['val_' + metric_hist] + history['val_' + metric_hist]

plot_metrics(history, metric_list=metrics_history)

# %% [markdown]
# ## Scheduler learning rates

# %%
#@title
fig, ax1 = plt.subplots(1, 1, figsize=(20, 6))

plt.xlabel('Training Iterations')
plt.ylabel('Learning Rate')
plt.title("CLR")
plt.plot(oneCycleLR.history['lr'])
plt.show()

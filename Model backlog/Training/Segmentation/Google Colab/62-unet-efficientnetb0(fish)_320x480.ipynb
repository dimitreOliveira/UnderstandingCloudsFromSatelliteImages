# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Scripts/.' .

# %%
# !unzip -q '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Data/train_images320x480.zip'

# %% [markdown]
# ### Dependencies

# %%
from utillity_script_cloud_segmentation import *
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.

# %%
seed = 0
seed_everything(seed)
warnings.filterwarnings("ignore")

# %%
base_path = '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/'
data_path = base_path + 'Data/'
model_base_path = base_path + 'Models/files/segmentation/'
train_path = data_path + 'train.csv'
hold_out_set_path = data_path + 'hold-out.csv'
train_images_dest_path = 'train_images/'

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv(train_path)
hold_out_set = pd.read_csv(hold_out_set_path)

X_train = hold_out_set[hold_out_set['set'] == 'train']
X_val = hold_out_set[hold_out_set['set'] == 'validation']

print('Compete set samples:', len(train))
print('Train samples: ', len(X_train))
print('Validation samples: ', len(X_val))

# Preprocecss data
train['image'] = train['Image_Label'].apply(lambda x: x.split('_')[0])
train['Class'] = train['Image_Label'].apply(lambda x: x.split('_')[1])

# Only fish images
X_train = X_train[X_train['Fish'] == 1]
X_val = X_val[X_val['Fish'] == 1]
train = train[train['Class'] == 'Fish']

display(X_train.head())
# Out:
# Compete set samples: 22184
# Train samples:  4420
# Validation samples:  1105
#          image                                          Fish_mask  ... Sugar    set
# 2  bb31239.jpg  29 604 1429 604 2829 604 4229 604 5629 604 702...  ...     0  train
# 4  f13cbe0.jpg  330457 1020 331857 1020 333257 1020 334657 102...  ...     1  train
# 5  a0dd2ea.jpg  1703064 531 1704464 531 1705864 531 1707264 53...  ...     1  train
# 6  05a1aa8.jpg  11389 657 12789 657 14189 657 15589 657 16989 ...  ...     1  train
# 9  0dcd917.jpg  481752 562 483152 562 484552 562 485952 562 48...  ...     1  train
#
# [5 rows x 10 columns]

# %% [markdown]
# # Model parameters

# %%
BACKBONE = 'efficientnetb0'
BATCH_SIZE = 8
EPOCHS = 35
LEARNING_RATE = 3e-4
HEIGHT = 320
WIDTH = 480
CHANNELS = 3
N_CLASSES = 1
ES_PATIENCE = 8
RLROP_PATIENCE = 2
DECAY_DROP = 0.2
STEP_SIZE_TRAIN = len(X_train)//BATCH_SIZE
STEP_SIZE_VALID = len(X_val)//BATCH_SIZE

model_name = '62-unet_%s_%sx%s_(fish)' % (BACKBONE, HEIGHT, WIDTH)
model_path = model_base_path + '%s.h5' % (model_name)

# %%
preprocessing = sm.get_preprocessing(BACKBONE)

augmentation = albu.Compose([albu.HorizontalFlip(p=0.5),
                             albu.VerticalFlip(p=0.5),
                             albu.GridDistortion(p=0.5),
                             albu.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, 
                                                   shift_limit=0.1, border_mode=0, p=0.5)
                            ])

# %% [markdown]
# ### Data generator

# %%
train_generator = DataGenerator(
                  directory=train_images_dest_path,
                  dataframe=X_train,
                  target_df=train,
                  batch_size=BATCH_SIZE,
                  target_size=(HEIGHT, WIDTH),
                  n_channels=CHANNELS,
                  n_classes=N_CLASSES,
                  preprocessing=preprocessing,
                  augmentation=augmentation,
                  seed=seed)

valid_generator = DataGenerator(
                  directory=train_images_dest_path,
                  dataframe=X_val,
                  target_df=train,
                  batch_size=BATCH_SIZE, 
                  target_size=(HEIGHT, WIDTH),
                  n_channels=CHANNELS,
                  n_classes=N_CLASSES,
                  preprocessing=preprocessing,
                  seed=seed)

# %% [markdown]
# # Model

# %%
model = sm.FPN(backbone_name=BACKBONE, 
                encoder_weights='imagenet',
                classes=N_CLASSES,
                activation='sigmoid',
                input_shape=(None, None, CHANNELS))

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', save_best_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, verbose=1)

metric_list = [dice_coef, sm.metrics.iou_score, sm.metrics.f1_score]
callback_list = [checkpoint, es, rlrop]
optimizer = RAdam(learning_rate=LEARNING_RATE, warmup_proportion=0.1)

model.compile(optimizer=optimizer, loss=sm.losses.bce_dice_loss, metrics=metric_list)
# model.summary()

# %%
history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator,
                              validation_steps=STEP_SIZE_VALID,
                              callbacks=callback_list,
                              epochs=EPOCHS,
                              verbose=1).history
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/35
# 277/277 [==============================] - 604s 2s/step - loss: 1.0138 - dice_coef: 0.4848 - iou_score: 0.3232 - f1-score: 0.4848 - val_loss: 1.0182 - val_dice_coef: 0.5834 - val_iou_score: 0.4146 - val_f1-score: 0.5834
# Epoch 2/35
# 277/277 [==============================] - 553s 2s/step - loss: 0.8825 - dice_coef: 0.5576 - iou_score: 0.3888 - f1-score: 0.5576 - val_loss: 0.8914 - val_dice_coef: 0.5781 - val_iou_score: 0.4090 - val_f1-score: 0.5781
# Epoch 3/35
# 277/277 [==============================] - 556s 2s/step - loss: 0.8436 - dice_coef: 0.5766 - iou_score: 0.4074 - f1-score: 0.5766 - val_loss: 0.8918 - val_dice_coef: 0.6133 - val_iou_score: 0.4445 - val_f1-score: 0.6133
# Epoch 4/35
# 277/277 [==============================] - 545s 2s/step - loss: 0.8254 - dice_coef: 0.5861 - iou_score: 0.4169 - f1-score: 0.5861 - val_loss: 0.8468 - val_dice_coef: 0.5965 - val_iou_score: 0.4276 - val_f1-score: 0.5965
# Epoch 5/35
# 277/277 [==============================] - 552s 2s/step - loss: 0.8116 - dice_coef: 0.5952 - iou_score: 0.4264 - f1-score: 0.5952 - val_loss: 0.8718 - val_dice_coef: 0.6138 - val_iou_score: 0.4450 - val_f1-score: 0.6138
# Epoch 6/35
# 277/277 [==============================] - 552s 2s/step - loss: 0.7929 - dice_coef: 0.6060 - iou_score: 0.4372 - f1-score: 0.6060 - val_loss: 0.8410 - val_dice_coef: 0.6056 - val_iou_score: 0.4380 - val_f1-score: 0.6056
# Epoch 7/35
# 277/277 [==============================] - 555s 2s/step - loss: 0.7898 - dice_coef: 0.6080 - iou_score: 0.4395 - f1-score: 0.6080 - val_loss: 0.8484 - val_dice_coef: 0.6061 - val_iou_score: 0.4378 - val_f1-score: 0.6061
# Epoch 8/35
# 277/277 [==============================] - 549s 2s/step - loss: 0.7782 - dice_coef: 0.6132 - iou_score: 0.4446 - f1-score: 0.6132 - val_loss: 0.8388 - val_dice_coef: 0.6139 - val_iou_score: 0.4462 - val_f1-score: 0.6139
# Epoch 9/35
# 277/277 [==============================] - 558s 2s/step - loss: 0.7742 - dice_coef: 0.6153 - iou_score: 0.4471 - f1-score: 0.6153 - val_loss: 0.8780 - val_dice_coef: 0.6090 - val_iou_score: 0.4414 - val_f1-score: 0.6090
# Epoch 10/35
# 277/277 [==============================] - 559s 2s/step - loss: 0.7626 - dice_coef: 0.6230 - iou_score: 0.4553 - f1-score: 0.6230 - val_loss: 0.8528 - val_dice_coef: 0.6120 - val_iou_score: 0.4449 - val_f1-score: 0.6120
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 6.000000284984708e-05.
# Epoch 11/35
# 277/277 [==============================] - 546s 2s/step - loss: 0.7142 - dice_coef: 0.6463 - iou_score: 0.4798 - f1-score: 0.6463 - val_loss: 0.8229 - val_dice_coef: 0.6213 - val_iou_score: 0.4544 - val_f1-score: 0.6213
# Epoch 12/35
# 277/277 [==============================] - 554s 2s/step - loss: 0.7048 - dice_coef: 0.6520 - iou_score: 0.4863 - f1-score: 0.6520 - val_loss: 0.8282 - val_dice_coef: 0.6220 - val_iou_score: 0.4539 - val_f1-score: 0.6220
# Epoch 13/35
# 277/277 [==============================] - 552s 2s/step - loss: 0.6970 - dice_coef: 0.6572 - iou_score: 0.4921 - f1-score: 0.6572 - val_loss: 0.8305 - val_dice_coef: 0.6250 - val_iou_score: 0.4580 - val_f1-score: 0.6250
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.2000000424450263e-05.
# Epoch 14/35
# 277/277 [==============================] - 555s 2s/step - loss: 0.6749 - dice_coef: 0.6657 - iou_score: 0.5020 - f1-score: 0.6657 - val_loss: 0.8363 - val_dice_coef: 0.6285 - val_iou_score: 0.4618 - val_f1-score: 0.6285
# Epoch 15/35
# 277/277 [==============================] - 548s 2s/step - loss: 0.6672 - dice_coef: 0.6713 - iou_score: 0.5082 - f1-score: 0.6713 - val_loss: 0.8411 - val_dice_coef: 0.6300 - val_iou_score: 0.4633 - val_f1-score: 0.6300
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.4000000848900527e-06.
# Epoch 16/35
# 277/277 [==============================] - 551s 2s/step - loss: 0.6636 - dice_coef: 0.6750 - iou_score: 0.5122 - f1-score: 0.6750 - val_loss: 0.8405 - val_dice_coef: 0.6322 - val_iou_score: 0.4651 - val_f1-score: 0.6322
# Epoch 17/35
# 277/277 [==============================] - 552s 2s/step - loss: 0.6736 - dice_coef: 0.6708 - iou_score: 0.5072 - f1-score: 0.6708 - val_loss: 0.8436 - val_dice_coef: 0.6296 - val_iou_score: 0.4633 - val_f1-score: 0.6296
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 4.800000169780105e-07.
# Epoch 18/35
# 277/277 [==============================] - 550s 2s/step - loss: 0.6552 - dice_coef: 0.6777 - iou_score: 0.5153 - f1-score: 0.6777 - val_loss: 0.8380 - val_dice_coef: 0.6333 - val_iou_score: 0.4668 - val_f1-score: 0.6333
# Epoch 19/35
# 277/277 [==============================] - 548s 2s/step - loss: 0.6637 - dice_coef: 0.6743 - iou_score: 0.5114 - f1-score: 0.6743 - val_loss: 0.8402 - val_dice_coef: 0.6327 - val_iou_score: 0.4657 - val_f1-score: 0.6327
# Restoring model weights from the end of the best epoch
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 9.600000794307562e-08.
# Epoch 00019: early stopping

# %% [markdown]
# ## Model loss graph

# %%
#@title
plot_metrics(history, metric_list=['loss', 'dice_coef', 'iou_score', 'f1-score'])

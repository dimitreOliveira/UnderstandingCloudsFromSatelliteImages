# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Scripts/.' .

# %%
# !unzip -q '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Data/train_images320x480.zip'

# %% [markdown]
# ### Dependencies

# %%
from utillity_script_cloud_segmentation import *
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.

# %%
seed = 0
seed_everything(seed)
warnings.filterwarnings("ignore")

# %%
base_path = '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/'
data_path = base_path + 'Data/'
model_base_path = base_path + 'Models/files/segmentation/'
train_path = data_path + 'train.csv'
hold_out_set_path = data_path + 'hold-out.csv'
train_images_dest_path = 'train_images/'

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv(train_path)
hold_out_set = pd.read_csv(hold_out_set_path)

X_train = hold_out_set[hold_out_set['set'] == 'train']
X_val = hold_out_set[hold_out_set['set'] == 'validation']

print('Compete set samples:', len(train))
print('Train samples: ', len(X_train))
print('Validation samples: ', len(X_val))

# Preprocecss data
train['image'] = train['Image_Label'].apply(lambda x: x.split('_')[0])
train['Class'] = train['Image_Label'].apply(lambda x: x.split('_')[1])

# Only Flower images
X_train = X_train[X_train['Flower'] == 1]
X_val = X_val[X_val['Flower'] == 1]
train = train[train['Class'] == 'Flower']

display(X_train.head())
# Out:
# Compete set samples: 22184
# Train samples:  4420
# Validation samples:  1105
#           image  ...    set
# 2   bb31239.jpg  ...  train
# 4   f13cbe0.jpg  ...  train
# 5   a0dd2ea.jpg  ...  train
# 7   affb040.jpg  ...  train
# 10  d8cdb15.jpg  ...  train
#
# [5 rows x 10 columns]

# %% [markdown]
# # Model parameters

# %%
BACKBONE = 'efficientnetb0'
BATCH_SIZE = 8
EPOCHS = 35
LEARNING_RATE = 3e-4
HEIGHT = 320
WIDTH = 480
CHANNELS = 3
N_CLASSES = 1
ES_PATIENCE = 8
RLROP_PATIENCE = 2
DECAY_DROP = 0.2
STEP_SIZE_TRAIN = len(X_train)//BATCH_SIZE
STEP_SIZE_VALID = len(X_val)//BATCH_SIZE

model_name = '62-unet_%s_%sx%s_(flower)' % (BACKBONE, HEIGHT, WIDTH)
model_path = model_base_path + '%s.h5' % (model_name)

# %%
preprocessing = sm.get_preprocessing(BACKBONE)

augmentation = albu.Compose([albu.HorizontalFlip(p=0.5),
                             albu.VerticalFlip(p=0.5),
                             albu.GridDistortion(p=0.5),
                             albu.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, 
                                                   shift_limit=0.1, border_mode=0, p=0.5)
                            ])

# %% [markdown]
# ### Data generator

# %%
train_generator = DataGenerator(
                  directory=train_images_dest_path,
                  dataframe=X_train,
                  target_df=train,
                  batch_size=BATCH_SIZE,
                  target_size=(HEIGHT, WIDTH),
                  n_channels=CHANNELS,
                  n_classes=N_CLASSES,
                  preprocessing=preprocessing,
                  augmentation=augmentation,
                  seed=seed)

valid_generator = DataGenerator(
                  directory=train_images_dest_path,
                  dataframe=X_val,
                  target_df=train,
                  batch_size=BATCH_SIZE, 
                  target_size=(HEIGHT, WIDTH),
                  n_channels=CHANNELS,
                  n_classes=N_CLASSES,
                  preprocessing=preprocessing,
                  seed=seed)

# %% [markdown]
# # Model

# %%
model = sm.FPN(backbone_name=BACKBONE, 
                encoder_weights='imagenet',
                classes=N_CLASSES,
                activation='sigmoid',
                input_shape=(None, None, CHANNELS))

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', save_best_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, verbose=1)

metric_list = [dice_coef, sm.metrics.iou_score, sm.metrics.f1_score]
callback_list = [checkpoint, es, rlrop]
optimizer = RAdam(learning_rate=LEARNING_RATE, warmup_proportion=0.1)

model.compile(optimizer=optimizer, loss=sm.losses.bce_dice_loss, metrics=metric_list)
# model.summary()

# %%
history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator,
                              validation_steps=STEP_SIZE_VALID,
                              callbacks=callback_list,
                              epochs=EPOCHS,
                              verbose=1).history
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/35
# 236/236 [==============================] - 530s 2s/step - loss: 0.8850 - dice_coef: 0.5734 - iou_score: 0.4085 - f1-score: 0.5734 - val_loss: 0.8070 - val_dice_coef: 0.6942 - val_iou_score: 0.5366 - val_f1-score: 0.6942
# Epoch 2/35
# 236/236 [==============================] - 482s 2s/step - loss: 0.7249 - dice_coef: 0.6572 - iou_score: 0.4922 - f1-score: 0.6572 - val_loss: 0.7063 - val_dice_coef: 0.7103 - val_iou_score: 0.5537 - val_f1-score: 0.7103
# Epoch 3/35
# 236/236 [==============================] - 482s 2s/step - loss: 0.6889 - dice_coef: 0.6747 - iou_score: 0.5119 - f1-score: 0.6747 - val_loss: 0.6976 - val_dice_coef: 0.7041 - val_iou_score: 0.5469 - val_f1-score: 0.7041
# Epoch 4/35
# 236/236 [==============================] - 483s 2s/step - loss: 0.6677 - dice_coef: 0.6824 - iou_score: 0.5208 - f1-score: 0.6824 - val_loss: 0.6507 - val_dice_coef: 0.7249 - val_iou_score: 0.5705 - val_f1-score: 0.7249
# Epoch 5/35
# 236/236 [==============================] - 483s 2s/step - loss: 0.6448 - dice_coef: 0.6956 - iou_score: 0.5359 - f1-score: 0.6956 - val_loss: 0.6719 - val_dice_coef: 0.7217 - val_iou_score: 0.5673 - val_f1-score: 0.7217
# Epoch 6/35
# 236/236 [==============================] - 482s 2s/step - loss: 0.6465 - dice_coef: 0.6950 - iou_score: 0.5355 - f1-score: 0.6950 - val_loss: 0.6594 - val_dice_coef: 0.7275 - val_iou_score: 0.5754 - val_f1-score: 0.7275
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 6.000000284984708e-05.
# Epoch 7/35
# 236/236 [==============================] - 482s 2s/step - loss: 0.6114 - dice_coef: 0.7090 - iou_score: 0.5516 - f1-score: 0.7090 - val_loss: 0.6317 - val_dice_coef: 0.7252 - val_iou_score: 0.5722 - val_f1-score: 0.7252
# Epoch 8/35
# 236/236 [==============================] - 480s 2s/step - loss: 0.6075 - dice_coef: 0.7110 - iou_score: 0.5543 - f1-score: 0.7110 - val_loss: 0.6461 - val_dice_coef: 0.7128 - val_iou_score: 0.5564 - val_f1-score: 0.7128
# Epoch 9/35
# 236/236 [==============================] - 480s 2s/step - loss: 0.5974 - dice_coef: 0.7185 - iou_score: 0.5637 - f1-score: 0.7185 - val_loss: 0.6412 - val_dice_coef: 0.7307 - val_iou_score: 0.5783 - val_f1-score: 0.7307
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1.2000000424450263e-05.
# Epoch 10/35
# 236/236 [==============================] - 481s 2s/step - loss: 0.5939 - dice_coef: 0.7182 - iou_score: 0.5636 - f1-score: 0.7182 - val_loss: 0.6296 - val_dice_coef: 0.7302 - val_iou_score: 0.5776 - val_f1-score: 0.7302
# Epoch 11/35
# 236/236 [==============================] - 481s 2s/step - loss: 0.5921 - dice_coef: 0.7197 - iou_score: 0.5656 - f1-score: 0.7197 - val_loss: 0.6327 - val_dice_coef: 0.7280 - val_iou_score: 0.5752 - val_f1-score: 0.7280
# Epoch 12/35
# 236/236 [==============================] - 481s 2s/step - loss: 0.5957 - dice_coef: 0.7200 - iou_score: 0.5653 - f1-score: 0.7200 - val_loss: 0.6269 - val_dice_coef: 0.7312 - val_iou_score: 0.5785 - val_f1-score: 0.7312
# Epoch 13/35
# 236/236 [==============================] - 481s 2s/step - loss: 0.5712 - dice_coef: 0.7317 - iou_score: 0.5792 - f1-score: 0.7317 - val_loss: 0.6325 - val_dice_coef: 0.7330 - val_iou_score: 0.5817 - val_f1-score: 0.7330
# Epoch 14/35
# 236/236 [==============================] - 482s 2s/step - loss: 0.5806 - dice_coef: 0.7271 - iou_score: 0.5743 - f1-score: 0.7271 - val_loss: 0.6303 - val_dice_coef: 0.7323 - val_iou_score: 0.5802 - val_f1-score: 0.7323
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.4000000848900527e-06.
# Epoch 15/35
# 236/236 [==============================] - 480s 2s/step - loss: 0.5854 - dice_coef: 0.7240 - iou_score: 0.5703 - f1-score: 0.7240 - val_loss: 0.6321 - val_dice_coef: 0.7295 - val_iou_score: 0.5767 - val_f1-score: 0.7295
# Epoch 16/35
# 236/236 [==============================] - 481s 2s/step - loss: 0.5806 - dice_coef: 0.7254 - iou_score: 0.5715 - f1-score: 0.7254 - val_loss: 0.6313 - val_dice_coef: 0.7317 - val_iou_score: 0.5796 - val_f1-score: 0.7317
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 4.800000169780105e-07.
# Epoch 17/35
# 236/236 [==============================] - 480s 2s/step - loss: 0.5717 - dice_coef: 0.7286 - iou_score: 0.5757 - f1-score: 0.7286 - val_loss: 0.6301 - val_dice_coef: 0.7326 - val_iou_score: 0.5803 - val_f1-score: 0.7326
# Epoch 18/35
# 236/236 [==============================] - 480s 2s/step - loss: 0.5736 - dice_coef: 0.7295 - iou_score: 0.5770 - f1-score: 0.7295 - val_loss: 0.6297 - val_dice_coef: 0.7323 - val_iou_score: 0.5798 - val_f1-score: 0.7323
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 9.600000794307562e-08.
# Epoch 19/35
# 236/236 [==============================] - 480s 2s/step - loss: 0.5677 - dice_coef: 0.7298 - iou_score: 0.5772 - f1-score: 0.7298 - val_loss: 0.6326 - val_dice_coef: 0.7306 - val_iou_score: 0.5789 - val_f1-score: 0.7306
# Epoch 20/35
# 236/236 [==============================] - 482s 2s/step - loss: 0.5723 - dice_coef: 0.7294 - iou_score: 0.5767 - f1-score: 0.7294 - val_loss: 0.6313 - val_dice_coef: 0.7330 - val_iou_score: 0.5816 - val_f1-score: 0.7330
# Restoring model weights from the end of the best epoch
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.9200001588615123e-08.
# Epoch 00020: early stopping

# %% [markdown]
# ## Model loss graph

# %%
#@title
plot_metrics(history, metric_list=['loss', 'dice_coef', 'iou_score', 'f1-score'])

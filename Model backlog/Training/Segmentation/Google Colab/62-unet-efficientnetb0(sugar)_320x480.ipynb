# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Scripts/.' .

# %%
# !unzip -q '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Data/train_images320x480.zip'

# %% [markdown]
# ### Dependencies

# %%
from utillity_script_cloud_segmentation import *
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.

# %%
seed = 0
seed_everything(seed)
warnings.filterwarnings("ignore")

# %%
base_path = '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/'
data_path = base_path + 'Data/'
model_base_path = base_path + 'Models/files/segmentation/'
train_path = data_path + 'train.csv'
hold_out_set_path = data_path + 'hold-out.csv'
train_images_dest_path = 'train_images/'

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv(train_path)
hold_out_set = pd.read_csv(hold_out_set_path)

X_train = hold_out_set[hold_out_set['set'] == 'train']
X_val = hold_out_set[hold_out_set['set'] == 'validation']

print('Compete set samples:', len(train))
print('Train samples: ', len(X_train))
print('Validation samples: ', len(X_val))

# Preprocecss data
train['image'] = train['Image_Label'].apply(lambda x: x.split('_')[0])
train['Class'] = train['Image_Label'].apply(lambda x: x.split('_')[1])

# Only Sugar images
X_train = X_train[X_train['Sugar'] == 1]
X_val = X_val[X_val['Sugar'] == 1]
train = train[train['Class'] == 'Sugar']

display(X_train.head())
# Out:
# Compete set samples: 22184
# Train samples:  4420
# Validation samples:  1105
#          image                                          Fish_mask  ... Sugar    set
# 0  66cda54.jpg                                                NaN  ...     1  train
# 1  61d6640.jpg                                                NaN  ...     1  train
# 4  f13cbe0.jpg  330457 1020 331857 1020 333257 1020 334657 102...  ...     1  train
# 5  a0dd2ea.jpg  1703064 531 1704464 531 1705864 531 1707264 53...  ...     1  train
# 6  05a1aa8.jpg  11389 657 12789 657 14189 657 15589 657 16989 ...  ...     1  train
#
# [5 rows x 10 columns]

# %% [markdown]
# # Model parameters

# %%
BACKBONE = 'efficientnetb0'
BATCH_SIZE = 8
EPOCHS = 35
LEARNING_RATE = 3e-4
HEIGHT = 320
WIDTH = 480
CHANNELS = 3
N_CLASSES = 1
ES_PATIENCE = 8
RLROP_PATIENCE = 2
DECAY_DROP = 0.2
STEP_SIZE_TRAIN = len(X_train)//BATCH_SIZE
STEP_SIZE_VALID = len(X_val)//BATCH_SIZE

model_name = '62-unet_%s_%sx%s_(sugar)' % (BACKBONE, HEIGHT, WIDTH)
model_path = model_base_path + '%s.h5' % (model_name)

# %%
preprocessing = sm.get_preprocessing(BACKBONE)

augmentation = albu.Compose([albu.HorizontalFlip(p=0.5),
                             albu.VerticalFlip(p=0.5),
                             albu.GridDistortion(p=0.5),
                             albu.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, 
                                                   shift_limit=0.1, border_mode=0, p=0.5)
                            ])

# %% [markdown]
# ### Data generator

# %%
train_generator = DataGenerator(
                  directory=train_images_dest_path,
                  dataframe=X_train,
                  target_df=train,
                  batch_size=BATCH_SIZE,
                  target_size=(HEIGHT, WIDTH),
                  n_channels=CHANNELS,
                  n_classes=N_CLASSES,
                  preprocessing=preprocessing,
                  augmentation=augmentation,
                  seed=seed)

valid_generator = DataGenerator(
                  directory=train_images_dest_path,
                  dataframe=X_val,
                  target_df=train,
                  batch_size=BATCH_SIZE, 
                  target_size=(HEIGHT, WIDTH),
                  n_channels=CHANNELS,
                  n_classes=N_CLASSES,
                  preprocessing=preprocessing,
                  seed=seed)

# %% [markdown]
# # Model

# %%
model = sm.FPN(backbone_name=BACKBONE, 
                encoder_weights='imagenet',
                classes=N_CLASSES,
                activation='sigmoid',
                input_shape=(None, None, CHANNELS))

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', save_best_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, verbose=1)

metric_list = [dice_coef, sm.metrics.iou_score, sm.metrics.f1_score]
callback_list = [checkpoint, es, rlrop]
optimizer = RAdam(learning_rate=LEARNING_RATE, warmup_proportion=0.1)

model.compile(optimizer=optimizer, loss=sm.losses.bce_dice_loss, metrics=metric_list)
# model.summary()

# %%
history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator,
                              validation_steps=STEP_SIZE_VALID,
                              callbacks=callback_list,
                              epochs=EPOCHS,
                              verbose=1).history
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/35
# 373/373 [==============================] - 775s 2s/step - loss: 0.8786 - dice_coef: 0.5281 - iou_score: 0.3640 - f1-score: 0.5281 - val_loss: 0.8869 - val_dice_coef: 0.6429 - val_iou_score: 0.4772 - val_f1-score: 0.6429
# Epoch 2/35
# 373/373 [==============================] - 732s 2s/step - loss: 0.7580 - dice_coef: 0.5957 - iou_score: 0.4272 - f1-score: 0.5957 - val_loss: 0.7398 - val_dice_coef: 0.6513 - val_iou_score: 0.4863 - val_f1-score: 0.6513
# Epoch 3/35
# 373/373 [==============================] - 732s 2s/step - loss: 0.7410 - dice_coef: 0.6035 - iou_score: 0.4349 - f1-score: 0.6035 - val_loss: 0.7240 - val_dice_coef: 0.6560 - val_iou_score: 0.4925 - val_f1-score: 0.6560
# Epoch 4/35
# 373/373 [==============================] - 732s 2s/step - loss: 0.7211 - dice_coef: 0.6172 - iou_score: 0.4495 - f1-score: 0.6172 - val_loss: 0.7355 - val_dice_coef: 0.6576 - val_iou_score: 0.4941 - val_f1-score: 0.6576
# Epoch 5/35
# 373/373 [==============================] - 732s 2s/step - loss: 0.7068 - dice_coef: 0.6246 - iou_score: 0.4570 - f1-score: 0.6246 - val_loss: 0.7122 - val_dice_coef: 0.6499 - val_iou_score: 0.4856 - val_f1-score: 0.6499
# Epoch 6/35
# 373/373 [==============================] - 732s 2s/step - loss: 0.7070 - dice_coef: 0.6244 - iou_score: 0.4571 - f1-score: 0.6244 - val_loss: 0.7204 - val_dice_coef: 0.6594 - val_iou_score: 0.4950 - val_f1-score: 0.6594
# Epoch 7/35
# 373/373 [==============================] - 732s 2s/step - loss: 0.7002 - dice_coef: 0.6295 - iou_score: 0.4626 - f1-score: 0.6295 - val_loss: 0.6996 - val_dice_coef: 0.6518 - val_iou_score: 0.4865 - val_f1-score: 0.6518
# Epoch 8/35
# 373/373 [==============================] - 734s 2s/step - loss: 0.7002 - dice_coef: 0.6288 - iou_score: 0.4613 - f1-score: 0.6288 - val_loss: 0.6971 - val_dice_coef: 0.6477 - val_iou_score: 0.4827 - val_f1-score: 0.6477
# Epoch 9/35
# 373/373 [==============================] - 733s 2s/step - loss: 0.6892 - dice_coef: 0.6329 - iou_score: 0.4661 - f1-score: 0.6329 - val_loss: 0.7084 - val_dice_coef: 0.6431 - val_iou_score: 0.4787 - val_f1-score: 0.6431
# Epoch 10/35
# 373/373 [==============================] - 733s 2s/step - loss: 0.6787 - dice_coef: 0.6399 - iou_score: 0.4736 - f1-score: 0.6399 - val_loss: 0.7294 - val_dice_coef: 0.6494 - val_iou_score: 0.4853 - val_f1-score: 0.6494
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 6.000000284984708e-05.
# Epoch 11/35
# 373/373 [==============================] - 734s 2s/step - loss: 0.6521 - dice_coef: 0.6525 - iou_score: 0.4871 - f1-score: 0.6525 - val_loss: 0.7011 - val_dice_coef: 0.6564 - val_iou_score: 0.4926 - val_f1-score: 0.6564
# Epoch 12/35
# 373/373 [==============================] - 734s 2s/step - loss: 0.6473 - dice_coef: 0.6587 - iou_score: 0.4941 - f1-score: 0.6587 - val_loss: 0.7007 - val_dice_coef: 0.6576 - val_iou_score: 0.4944 - val_f1-score: 0.6576
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.2000000424450263e-05.
# Epoch 13/35
# 373/373 [==============================] - 735s 2s/step - loss: 0.6394 - dice_coef: 0.6591 - iou_score: 0.4952 - f1-score: 0.6591 - val_loss: 0.6984 - val_dice_coef: 0.6602 - val_iou_score: 0.4971 - val_f1-score: 0.6602
# Epoch 14/35
# 373/373 [==============================] - 732s 2s/step - loss: 0.6211 - dice_coef: 0.6694 - iou_score: 0.5061 - f1-score: 0.6694 - val_loss: 0.7019 - val_dice_coef: 0.6630 - val_iou_score: 0.5006 - val_f1-score: 0.6630
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.4000000848900527e-06.
# Epoch 15/35
# 373/373 [==============================] - 733s 2s/step - loss: 0.6212 - dice_coef: 0.6709 - iou_score: 0.5080 - f1-score: 0.6709 - val_loss: 0.6993 - val_dice_coef: 0.6639 - val_iou_score: 0.5010 - val_f1-score: 0.6639
# Epoch 16/35
# 373/373 [==============================] - 733s 2s/step - loss: 0.6171 - dice_coef: 0.6739 - iou_score: 0.5113 - f1-score: 0.6739 - val_loss: 0.7036 - val_dice_coef: 0.6611 - val_iou_score: 0.4977 - val_f1-score: 0.6611
# Restoring model weights from the end of the best epoch
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 4.800000169780105e-07.
# Epoch 00016: early stopping

# %% [markdown]
# ## Model loss graph

# %%
#@title
plot_metrics(history, metric_list=['loss', 'dice_coef', 'iou_score', 'f1-score'])

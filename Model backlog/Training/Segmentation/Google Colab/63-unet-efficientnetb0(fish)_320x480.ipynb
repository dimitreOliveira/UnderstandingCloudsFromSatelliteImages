# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Scripts/.' .

# %%
# !unzip -q '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Data/train_images320x480.zip'

# %% [markdown]
# ### Dependencies

# %%
from utillity_script_cloud_segmentation import *
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.

# %%
seed = 0
seed_everything(seed)
warnings.filterwarnings("ignore")

# %%
base_path = '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/'
data_path = base_path + 'Data/'
model_base_path = base_path + 'Models/files/segmentation/'
train_path = data_path + 'train.csv'
hold_out_set_path = data_path + 'hold-out.csv'
train_images_dest_path = 'train_images/'

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv(train_path)
hold_out_set = pd.read_csv(hold_out_set_path)

X_train = hold_out_set[hold_out_set['set'] == 'train']
X_val = hold_out_set[hold_out_set['set'] == 'validation']

print('Compete set samples:', len(train))
print('Train samples: ', len(X_train))
print('Validation samples: ', len(X_val))

# Preprocecss data
train['image'] = train['Image_Label'].apply(lambda x: x.split('_')[0])
train['Class'] = train['Image_Label'].apply(lambda x: x.split('_')[1])

# Only fish images
train = train[train['Class'] == 'Fish']

display(X_train.head())
# Out:
# Compete set samples: 22184
# Train samples:  4420
# Validation samples:  1105
#          image                                          Fish_mask  ... Sugar    set
# 0  66cda54.jpg                                                NaN  ...     1  train
# 1  61d6640.jpg                                                NaN  ...     1  train
# 2  bb31239.jpg  29 604 1429 604 2829 604 4229 604 5629 604 702...  ...     0  train
# 3  74d06fc.jpg                                                NaN  ...     0  train
# 4  f13cbe0.jpg  330457 1020 331857 1020 333257 1020 334657 102...  ...     1  train
#
# [5 rows x 10 columns]

# %% [markdown]
# # Model parameters

# %%
BACKBONE = 'efficientnetb0'
BATCH_SIZE = 8
EPOCHS = 35
LEARNING_RATE = 3e-4
HEIGHT = 320
WIDTH = 480
CHANNELS = 3
N_CLASSES = 1
ES_PATIENCE = 8
RLROP_PATIENCE = 2
DECAY_DROP = 0.2
STEP_SIZE_TRAIN = len(X_train)//BATCH_SIZE
STEP_SIZE_VALID = len(X_val)//BATCH_SIZE

model_name = '63-unet_%s_%sx%s_(fish)' % (BACKBONE, HEIGHT, WIDTH)
model_path = model_base_path + '%s.h5' % (model_name)

# %%
preprocessing = sm.get_preprocessing(BACKBONE)

augmentation = albu.Compose([albu.HorizontalFlip(p=0.5),
                             albu.VerticalFlip(p=0.5),
                             albu.GridDistortion(p=0.5),
                             albu.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, 
                                                   shift_limit=0.1, border_mode=0, p=0.5)
                            ])

# %% [markdown]
# ### Data generator

# %%
train_generator = DataGenerator(
                  directory=train_images_dest_path,
                  dataframe=X_train,
                  target_df=train,
                  batch_size=BATCH_SIZE,
                  target_size=(HEIGHT, WIDTH),
                  n_channels=CHANNELS,
                  n_classes=N_CLASSES,
                  preprocessing=preprocessing,
                  augmentation=augmentation,
                  seed=seed)

valid_generator = DataGenerator(
                  directory=train_images_dest_path,
                  dataframe=X_val,
                  target_df=train,
                  batch_size=BATCH_SIZE, 
                  target_size=(HEIGHT, WIDTH),
                  n_channels=CHANNELS,
                  n_classes=N_CLASSES,
                  preprocessing=preprocessing,
                  seed=seed)

# %% [markdown]
# # Model

# %%
model = sm.FPN(backbone_name=BACKBONE, 
                encoder_weights='imagenet',
                classes=N_CLASSES,
                activation='sigmoid',
                input_shape=(None, None, CHANNELS))

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', save_best_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, verbose=1)

metric_list = [dice_coef, sm.metrics.iou_score, sm.metrics.f1_score]
callback_list = [checkpoint, es, rlrop]
optimizer = RAdam(learning_rate=LEARNING_RATE, warmup_proportion=0.1)

model.compile(optimizer=optimizer, loss=sm.losses.bce_dice_loss, metrics=metric_list)
# model.summary()

# %%
history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator,
                              validation_steps=STEP_SIZE_VALID,
                              callbacks=callback_list,
                              epochs=EPOCHS,
                              verbose=1).history
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/35
# 552/552 [==============================] - 1154s 2s/step - loss: 1.0245 - dice_coef: 0.3436 - iou_score: 0.2137 - f1-score: 0.3436 - val_loss: 0.9874 - val_dice_coef: 0.4409 - val_iou_score: 0.2913 - val_f1-score: 0.4409
# Epoch 2/35
# 552/552 [==============================] - 1114s 2s/step - loss: 0.9192 - dice_coef: 0.4101 - iou_score: 0.2662 - f1-score: 0.4101 - val_loss: 0.9076 - val_dice_coef: 0.4511 - val_iou_score: 0.3011 - val_f1-score: 0.4511
# Epoch 3/35
# 552/552 [==============================] - 1114s 2s/step - loss: 0.9015 - dice_coef: 0.4201 - iou_score: 0.2745 - f1-score: 0.4201 - val_loss: 0.8886 - val_dice_coef: 0.4506 - val_iou_score: 0.3014 - val_f1-score: 0.4506
# Epoch 4/35
# 552/552 [==============================] - 1111s 2s/step - loss: 0.8780 - dice_coef: 0.4365 - iou_score: 0.2885 - f1-score: 0.4365 - val_loss: 0.9196 - val_dice_coef: 0.4099 - val_iou_score: 0.2692 - val_f1-score: 0.4099
# Epoch 5/35
# 552/552 [==============================] - 1106s 2s/step - loss: 0.8749 - dice_coef: 0.4397 - iou_score: 0.2905 - f1-score: 0.4397 - val_loss: 0.9209 - val_dice_coef: 0.4073 - val_iou_score: 0.2625 - val_f1-score: 0.4073
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 6.000000284984708e-05.
# Epoch 6/35
# 552/552 [==============================] - 1108s 2s/step - loss: 0.8381 - dice_coef: 0.4623 - iou_score: 0.3098 - f1-score: 0.4623 - val_loss: 0.8558 - val_dice_coef: 0.4570 - val_iou_score: 0.3067 - val_f1-score: 0.4570
# Epoch 7/35
# 552/552 [==============================] - 1108s 2s/step - loss: 0.8089 - dice_coef: 0.4824 - iou_score: 0.3276 - f1-score: 0.4824 - val_loss: 0.8580 - val_dice_coef: 0.4674 - val_iou_score: 0.3173 - val_f1-score: 0.4674
# Epoch 8/35
# 552/552 [==============================] - 1108s 2s/step - loss: 0.8158 - dice_coef: 0.4775 - iou_score: 0.3236 - f1-score: 0.4775 - val_loss: 0.8542 - val_dice_coef: 0.4821 - val_iou_score: 0.3307 - val_f1-score: 0.4821
# Epoch 9/35
# 552/552 [==============================] - 1109s 2s/step - loss: 0.7951 - dice_coef: 0.4906 - iou_score: 0.3351 - f1-score: 0.4906 - val_loss: 0.8631 - val_dice_coef: 0.4817 - val_iou_score: 0.3307 - val_f1-score: 0.4817
# Epoch 10/35
# 552/552 [==============================] - 1111s 2s/step - loss: 0.7857 - dice_coef: 0.5008 - iou_score: 0.3436 - f1-score: 0.5008 - val_loss: 0.8683 - val_dice_coef: 0.4589 - val_iou_score: 0.3094 - val_f1-score: 0.4589
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.2000000424450263e-05.
# Epoch 11/35
# 552/552 [==============================] - 1106s 2s/step - loss: 0.7874 - dice_coef: 0.4947 - iou_score: 0.3386 - f1-score: 0.4947 - val_loss: 0.8520 - val_dice_coef: 0.4827 - val_iou_score: 0.3306 - val_f1-score: 0.4827
# Epoch 12/35
# 552/552 [==============================] - 1103s 2s/step - loss: 0.7787 - dice_coef: 0.5009 - iou_score: 0.3448 - f1-score: 0.5009 - val_loss: 0.8561 - val_dice_coef: 0.4752 - val_iou_score: 0.3251 - val_f1-score: 0.4752
# Epoch 13/35
# 552/552 [==============================] - 1102s 2s/step - loss: 0.7687 - dice_coef: 0.5097 - iou_score: 0.3519 - f1-score: 0.5097 - val_loss: 0.8608 - val_dice_coef: 0.4766 - val_iou_score: 0.3266 - val_f1-score: 0.4766
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 2.4000000848900527e-06.
# Epoch 14/35
# 552/552 [==============================] - 1103s 2s/step - loss: 0.7660 - dice_coef: 0.5105 - iou_score: 0.3536 - f1-score: 0.5105 - val_loss: 0.8581 - val_dice_coef: 0.4780 - val_iou_score: 0.3271 - val_f1-score: 0.4780
# Epoch 15/35
# 552/552 [==============================] - 1103s 2s/step - loss: 0.7574 - dice_coef: 0.5165 - iou_score: 0.3585 - f1-score: 0.5165 - val_loss: 0.8650 - val_dice_coef: 0.4701 - val_iou_score: 0.3202 - val_f1-score: 0.4701
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 4.800000169780105e-07.
# Epoch 16/35
# 552/552 [==============================] - 1104s 2s/step - loss: 0.7609 - dice_coef: 0.5122 - iou_score: 0.3543 - f1-score: 0.5122 - val_loss: 0.8527 - val_dice_coef: 0.4824 - val_iou_score: 0.3290 - val_f1-score: 0.4824
# Epoch 17/35
# 552/552 [==============================] - 1103s 2s/step - loss: 0.7720 - dice_coef: 0.5068 - iou_score: 0.3506 - f1-score: 0.5068 - val_loss: 0.8575 - val_dice_coef: 0.4788 - val_iou_score: 0.3283 - val_f1-score: 0.4788
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.600000794307562e-08.
# Epoch 18/35
# 552/552 [==============================] - 1103s 2s/step - loss: 0.7560 - dice_coef: 0.5167 - iou_score: 0.3578 - f1-score: 0.5167 - val_loss: 0.8533 - val_dice_coef: 0.4841 - val_iou_score: 0.3298 - val_f1-score: 0.4841
# Epoch 19/35
# 552/552 [==============================] - 1104s 2s/step - loss: 0.7556 - dice_coef: 0.5170 - iou_score: 0.3589 - f1-score: 0.5170 - val_loss: 0.8659 - val_dice_coef: 0.4750 - val_iou_score: 0.3267 - val_f1-score: 0.4750
# Restoring model weights from the end of the best epoch
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.9200001588615123e-08.
# Epoch 00019: early stopping

# %% [markdown]
# ## Model loss graph

# %%
#@title
plot_metrics(history, metric_list=['loss', 'dice_coef', 'iou_score', 'f1-score'])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Scripts/.' .

# %%
# !unzip -q '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/Data/train_images320x480.zip'

# %% [markdown]
# ### Dependencies

# %%
from utillity_script_cloud_segmentation import *
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.

# %%
#@title
from keras.optimizers import Optimizer

class AdamAccumulated(Optimizer):
    """Adam optimizer with gradient accumulation.
    Default parameters follow those provided in the original paper.
    # Arguments
        accumulation_steps: int > 0. Update gradient in every accumulation steps.
        lr: float >= 0. Learning rate.
        beta_1: float, 0 < beta < 1. Generally close to 1.
        beta_2: float, 0 < beta < 1. Generally close to 1.
        epsilon: float >= 0. Fuzz factor. If `None`, defaults to `K.epsilon()`.
        decay: float >= 0. Learning rate decay over each update.
        amsgrad: boolean. Whether to apply the AMSGrad variant of this
            algorithm from the paper "On the Convergence of Adam and Beyond".
    # References
        - [Adam - A Method for Stochastic Optimization](https://arxiv.org/abs/1412.6980v8)
        - [On the Convergence of Adam and Beyond](https://openreview.net/forum?id=ryQu7f-RZ)
    """

    def __init__(self, accumulation_steps, lr=0.001, beta_1=0.9, beta_2=0.999,
                 epsilon=None, decay=0., amsgrad=False, **kwargs):
        super(AdamAccumulated, self).__init__(**kwargs)
        with K.name_scope(self.__class__.__name__):
            self.iterations = K.variable(0, dtype='int64', name='iterations')
            self.accumulation_steps = K.variable(accumulation_steps, dtype='int64', name='accumulation_steps')
            self.lr = K.variable(lr, name='lr')
            self.beta_1 = K.variable(beta_1, name='beta_1')
            self.beta_2 = K.variable(beta_2, name='beta_2')
            self.decay = K.variable(decay, name='decay')
        if epsilon is None:
            epsilon = K.epsilon()
        self.epsilon = epsilon
        self.initial_decay = decay
        self.amsgrad = amsgrad

    def get_updates(self, loss, params):
        grads = self.get_gradients(loss, params)
        self.updates = [K.update_add(self.iterations, 1)]

        update_cond = K.equal((self.iterations + 1) % self.accumulation_steps, 0)
        sub_step = self.iterations % self.accumulation_steps + 1
        t = K.cast(self.iterations // self.accumulation_steps, K.floatx()) + 1

        lr = self.lr
        if self.initial_decay > 0:
            lr = lr * (1. / (1. + self.decay * K.cast(self.iterations, K.dtype(self.decay))))

        lr_t = lr * (K.sqrt(1. - K.pow(self.beta_2, t)) / (1. - K.pow(self.beta_1, t)))
        lr_t = K.switch(update_cond, lr_t, 0.0)

        ms = [K.zeros(K.int_shape(p), dtype=K.dtype(p), name='m_' + str(i)) for (i, p) in enumerate(params)]
        vs = [K.zeros(K.int_shape(p), dtype=K.dtype(p), name='v_' + str(i)) for (i, p) in enumerate(params)]

        if self.amsgrad:
            vhats = [K.zeros(K.int_shape(p), dtype=K.dtype(p), name='vhat_' + str(i)) for (i, p) in enumerate(params)]
        else:
            vhats = [K.zeros(1, name='vhat_' + str(i)) for i in range(len(params))]
        self.weights = [self.iterations] + ms + vs + vhats

        acc_grads = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
        for grad, acc_grad in zip(grads, acc_grads):
            ave_grad = grad / K.cast(self.accumulation_steps, K.floatx())
            self.updates.append(K.update(
                acc_grad,
                K.switch(
                    K.equal(sub_step, 1),
                    ave_grad,
                    acc_grad + (ave_grad - acc_grad) / K.cast(sub_step, K.floatx())
                ),
            ))
        grads = [K.switch(update_cond, grad, K.zeros_like(grad)) for grad in acc_grads]

        for p, g, m, v, vhat in zip(params, grads, ms, vs, vhats):
            m_t = K.switch(update_cond, (self.beta_1 * m) + (1. - self.beta_1) * g, m)
            v_t = K.switch(update_cond, (self.beta_2 * v) + (1. - self.beta_2) * K.square(g), v)
            if self.amsgrad:
                vhat_t = K.switch(update_cond, K.maximum(vhat, v_t), vhat)
                p_t = p - lr_t * m_t / (K.sqrt(vhat_t) + self.epsilon)
                self.updates.append(K.update(vhat, vhat_t))
            else:
                p_t = p - lr_t * m_t / (K.sqrt(v_t) + self.epsilon)

            self.updates.append(K.update(m, m_t))
            self.updates.append(K.update(v, v_t))
            new_p = p_t

            if getattr(p, 'constraint', None) is not None:
                new_p = p.constraint(new_p)

            self.updates.append(K.update(p, new_p))
        return self.updates

    def get_config(self):
        config = {'accumulation_steps': int(K.get_value(self.accumulation_steps)),
                  'lr': float(K.get_value(self.lr)),
                  'beta_1': float(K.get_value(self.beta_1)),
                  'beta_2': float(K.get_value(self.beta_2)),
                  'decay': float(K.get_value(self.decay)),
                  'epsilon': self.epsilon,
                  'amsgrad': self.amsgrad}
        base_config = super(AdamAccumulated, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
seed = 0
seed_everything(seed)
warnings.filterwarnings("ignore")
# Out:
# WARNING:tensorflow:From /content/utillity_script_cloud_segmentation.py:47: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.

# %%
base_path = '/content/drive/My Drive/Colab Notebooks/[Kaggle] Understanding Clouds from Satellite Images/'
data_path = base_path + 'Data/'
model_base_path = base_path + 'Models/files/segmentation/'
train_path = data_path + 'train.csv'
hold_out_set_path = data_path + 'hold-out.csv'
train_images_dest_path = 'train_images/'

# %% [markdown]
# ### Load data

# %%
train = pd.read_csv(train_path)
hold_out_set = pd.read_csv(hold_out_set_path)

X_train = hold_out_set[hold_out_set['set'] == 'train']
X_val = hold_out_set[hold_out_set['set'] == 'validation']

print('Compete set samples:', len(train))
print('Train samples: ', len(X_train))
print('Validation samples: ', len(X_val))

# Preprocecss data
train['image'] = train['Image_Label'].apply(lambda x: x.split('_')[0])

display(X_train.head())
# Out:
# Compete set samples: 22184
# Train samples:  4420
# Validation samples:  1105
#          image                                          Fish_mask  ... Sugar    set
# 0  1f3d231.jpg                                                NaN  ...     0  train
# 1  0fa3287.jpg                                                NaN  ...     1  train
# 2  4d17338.jpg  64 1141 1464 1141 2864 1141 4264 1141 5664 114...  ...     1  train
# 3  12e55a8.jpg                                                NaN  ...     1  train
# 4  697eb53.jpg  52180 1006 53580 1006 54980 1006 56380 1006 57...  ...     0  train
#
# [5 rows x 10 columns]

# %% [markdown]
# # Model parameters

# %%
BACKBONE = 'efficientnetb0'
BATCH_SIZE = 16
EPOCHS_WARMUP = 8
EPOCHS = 30
LEARNING_RATE = 3e-4
HEIGHT = 320
WIDTH = 480
CHANNELS = 3
N_CLASSES = 4
ES_PATIENCE = 5
RLROP_PATIENCE = 2
DECAY_DROP = 0.2
ACC_STEPS = 2
STEP_SIZE_TRAIN = len(X_train)//BATCH_SIZE
STEP_SIZE_VALID = len(X_val)//BATCH_SIZE

model_name = '70-unet_%s_%sx%s' % (BACKBONE, HEIGHT, WIDTH)
model_path = model_base_path + '%s.h5' % (model_name)

# %%
preprocessing = sm.get_preprocessing(BACKBONE)

augmentation = albu.Compose([albu.OneOf([
                                  albu.HorizontalFlip(p=0.5),
                                  albu.VerticalFlip(p=0.5),
                                  albu.Flip(p=0.5),
                                  ], p=0.6),
                             albu.OneOf([
                                  albu.GridDistortion(p=0.5),
                                  albu.OpticalDistortion(p=0.2),
                                  albu.ElasticTransform(p=0.5),
                                  ], p=0.4),
                             albu.OneOf([
                                  albu.RandomContrast(p=0.5),
                                  albu.RandomBrightnessContrast(p=0.5),
                                  ], p=0.5),
                             albu.OneOf([
                                  albu.RandomSizedCrop(min_max_height=(HEIGHT*0.9, HEIGHT), 
                                                        height=HEIGHT, width=WIDTH, p=0.5),
                                  albu.ShiftScaleRotate(scale_limit=0.2, rotate_limit=0, 
                                                        shift_limit=0.1, border_mode=0, p=0.5),
                                  ], p=0.3),
                            ])

# %% [markdown]
# ### Data generator

# %%
train_generator = DataGenerator(
                  directory=train_images_dest_path,
                  dataframe=X_train,
                  target_df=train,
                  batch_size=BATCH_SIZE,
                  target_size=(HEIGHT, WIDTH),
                  n_channels=CHANNELS,
                  n_classes=N_CLASSES,
                  preprocessing=preprocessing,
                  augmentation=augmentation,
                  seed=seed)

valid_generator = DataGenerator(
                  directory=train_images_dest_path,
                  dataframe=X_val,
                  target_df=train,
                  batch_size=BATCH_SIZE, 
                  target_size=(HEIGHT, WIDTH),
                  n_channels=CHANNELS,
                  n_classes=N_CLASSES,
                  preprocessing=preprocessing,
                  seed=seed)

# %% [markdown]
# # Warm Up (Batch Normalization)

# %%
model = sm.Unet(backbone_name=BACKBONE, 
                encoder_weights='imagenet',
                classes=N_CLASSES,
                activation='sigmoid',
                input_shape=(None, None, CHANNELS))

freeze_segmentation_model(model)
model.layers[-1].trainable = True

metric_list = [dice_coef, sm.metrics.iou_score, sm.metrics.f1_score]
optimizer = AdamAccumulated(lr=LEARNING_RATE, accumulation_steps=ACC_STEPS)

model.compile(optimizer=optimizer, loss=sm.losses.bce_dice_loss, metrics=metric_list)

# %%
history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator,
                              validation_steps=STEP_SIZE_VALID,
                              epochs=EPOCHS_WARMUP,
                              verbose=1).history
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/8
# 276/276 [==============================] - 632s 2s/step - loss: 1.6244 - dice_coef: 0.2355 - iou_score: 0.1313 - f1-score: 0.2299 - val_loss: 1.7080 - val_dice_coef: 0.2335 - val_iou_score: 0.1288 - val_f1-score: 0.2259
# Epoch 2/8
# 276/276 [==============================] - 581s 2s/step - loss: 1.5814 - dice_coef: 0.2362 - iou_score: 0.1319 - f1-score: 0.2311 - val_loss: 1.6444 - val_dice_coef: 0.2335 - val_iou_score: 0.1293 - val_f1-score: 0.2268
# Epoch 3/8
# 276/276 [==============================] - 581s 2s/step - loss: 1.5404 - dice_coef: 0.2371 - iou_score: 0.1324 - f1-score: 0.2318 - val_loss: 1.5924 - val_dice_coef: 0.2336 - val_iou_score: 0.1298 - val_f1-score: 0.2277
# Epoch 4/8
# 276/276 [==============================] - 584s 2s/step - loss: 1.5040 - dice_coef: 0.2378 - iou_score: 0.1328 - f1-score: 0.2326 - val_loss: 1.5521 - val_dice_coef: 0.2338 - val_iou_score: 0.1302 - val_f1-score: 0.2287
# Epoch 5/8
# 276/276 [==============================] - 579s 2s/step - loss: 1.4753 - dice_coef: 0.2381 - iou_score: 0.1328 - f1-score: 0.2324 - val_loss: 1.5153 - val_dice_coef: 0.2335 - val_iou_score: 0.1303 - val_f1-score: 0.2289
# Epoch 6/8
# 276/276 [==============================] - 567s 2s/step - loss: 1.4502 - dice_coef: 0.2384 - iou_score: 0.1331 - f1-score: 0.2330 - val_loss: 1.4838 - val_dice_coef: 0.2337 - val_iou_score: 0.1302 - val_f1-score: 0.2285
# Epoch 7/8
# 276/276 [==============================] - 578s 2s/step - loss: 1.4274 - dice_coef: 0.2388 - iou_score: 0.1334 - f1-score: 0.2336 - val_loss: 1.4585 - val_dice_coef: 0.2339 - val_iou_score: 0.1302 - val_f1-score: 0.2285
# Epoch 8/8
# 276/276 [==============================] - 588s 2s/step - loss: 1.4080 - dice_coef: 0.2391 - iou_score: 0.1334 - f1-score: 0.2334 - val_loss: 1.4343 - val_dice_coef: 0.2335 - val_iou_score: 0.1298 - val_f1-score: 0.2278

# %%
plot_metrics(history, metric_list=['loss', 'dice_coef', 'iou_score', 'f1-score'])

# %% [markdown]
# # Model

# %%
for layer in model.layers:
    layer.trainable = True
    
checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', save_best_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, verbose=1)

metric_list = [dice_coef, sm.metrics.iou_score, sm.metrics.f1_score]
callback_list = [checkpoint, es, rlrop]
optimizer = AdamAccumulated(lr=LEARNING_RATE, accumulation_steps=ACC_STEPS)

model.compile(optimizer=optimizer, loss=sm.losses.bce_dice_loss, metrics=metric_list)
# model.summary()

# %%
history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator,
                              validation_steps=STEP_SIZE_VALID,
                              callbacks=callback_list,
                              epochs=EPOCHS,
                              verbose=1).history
# Out:
# Epoch 1/30
# 276/276 [==============================] - 697s 3s/step - loss: 1.1448 - dice_coef: 0.3111 - iou_score: 0.1818 - f1-score: 0.3035 - val_loss: 1.1429 - val_dice_coef: 0.4347 - val_iou_score: 0.2783 - val_f1-score: 0.4302
# Epoch 2/30
# 276/276 [==============================] - 643s 2s/step - loss: 0.9406 - dice_coef: 0.4159 - iou_score: 0.2618 - f1-score: 0.4098 - val_loss: 0.8692 - val_dice_coef: 0.4887 - val_iou_score: 0.3184 - val_f1-score: 0.4750
# Epoch 3/30
# 276/276 [==============================] - 648s 2s/step - loss: 0.8844 - dice_coef: 0.4578 - iou_score: 0.2979 - f1-score: 0.4532 - val_loss: 0.8643 - val_dice_coef: 0.4961 - val_iou_score: 0.3300 - val_f1-score: 0.4883
# Epoch 4/30
# 276/276 [==============================] - 653s 2s/step - loss: 0.8718 - dice_coef: 0.4699 - iou_score: 0.3081 - f1-score: 0.4644 - val_loss: 0.8336 - val_dice_coef: 0.5107 - val_iou_score: 0.3398 - val_f1-score: 0.4976
# Epoch 5/30
# 276/276 [==============================] - 661s 2s/step - loss: 0.8546 - dice_coef: 0.4809 - iou_score: 0.3171 - f1-score: 0.4749 - val_loss: 0.8184 - val_dice_coef: 0.5119 - val_iou_score: 0.3389 - val_f1-score: 0.4966
# Epoch 6/30
# 276/276 [==============================] - 655s 2s/step - loss: 0.8380 - dice_coef: 0.4919 - iou_score: 0.3284 - f1-score: 0.4877 - val_loss: 0.8123 - val_dice_coef: 0.5228 - val_iou_score: 0.3494 - val_f1-score: 0.5096
# Epoch 7/30
# 276/276 [==============================] - 702s 3s/step - loss: 0.8314 - dice_coef: 0.4959 - iou_score: 0.3314 - f1-score: 0.4913 - val_loss: 0.7991 - val_dice_coef: 0.5368 - val_iou_score: 0.3611 - val_f1-score: 0.5215
# Epoch 8/30
# 276/276 [==============================] - 651s 2s/step - loss: 0.8176 - dice_coef: 0.5051 - iou_score: 0.3402 - f1-score: 0.5010 - val_loss: 0.7800 - val_dice_coef: 0.5346 - val_iou_score: 0.3587 - val_f1-score: 0.5185
# Epoch 9/30
# 276/276 [==============================] - 658s 2s/step - loss: 0.8238 - dice_coef: 0.5016 - iou_score: 0.3354 - f1-score: 0.4955 - val_loss: 0.7911 - val_dice_coef: 0.5241 - val_iou_score: 0.3460 - val_f1-score: 0.5033
# Epoch 10/30
# 276/276 [==============================] - 662s 2s/step - loss: 0.8083 - dice_coef: 0.5114 - iou_score: 0.3457 - f1-score: 0.5070 - val_loss: 0.7923 - val_dice_coef: 0.5392 - val_iou_score: 0.3581 - val_f1-score: 0.5161
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 6.000000284984708e-05.
# Epoch 11/30
# 276/276 [==============================] - 660s 2s/step - loss: 0.7954 - dice_coef: 0.5200 - iou_score: 0.3533 - f1-score: 0.5146 - val_loss: 0.7544 - val_dice_coef: 0.5478 - val_iou_score: 0.3733 - val_f1-score: 0.5359
# Epoch 12/30
# 276/276 [==============================] - 659s 2s/step - loss: 0.7830 - dice_coef: 0.5251 - iou_score: 0.3584 - f1-score: 0.5206 - val_loss: 0.7507 - val_dice_coef: 0.5468 - val_iou_score: 0.3723 - val_f1-score: 0.5344
# Epoch 13/30
# 276/276 [==============================] - 669s 2s/step - loss: 0.7756 - dice_coef: 0.5295 - iou_score: 0.3627 - f1-score: 0.5259 - val_loss: 0.7470 - val_dice_coef: 0.5541 - val_iou_score: 0.3785 - val_f1-score: 0.5411
# Epoch 14/30
# 276/276 [==============================] - 658s 2s/step - loss: 0.7759 - dice_coef: 0.5308 - iou_score: 0.3632 - f1-score: 0.5262 - val_loss: 0.7512 - val_dice_coef: 0.5516 - val_iou_score: 0.3708 - val_f1-score: 0.5314
# Epoch 15/30
# 276/276 [==============================] - 678s 2s/step - loss: 0.7725 - dice_coef: 0.5313 - iou_score: 0.3634 - f1-score: 0.5260 - val_loss: 0.7446 - val_dice_coef: 0.5521 - val_iou_score: 0.3774 - val_f1-score: 0.5399
# Epoch 16/30
# 276/276 [==============================] - 681s 2s/step - loss: 0.7689 - dice_coef: 0.5357 - iou_score: 0.3678 - f1-score: 0.5308 - val_loss: 0.7422 - val_dice_coef: 0.5530 - val_iou_score: 0.3793 - val_f1-score: 0.5423
# Epoch 17/30
# 276/276 [==============================] - 695s 3s/step - loss: 0.7689 - dice_coef: 0.5367 - iou_score: 0.3682 - f1-score: 0.5314 - val_loss: 0.7469 - val_dice_coef: 0.5582 - val_iou_score: 0.3825 - val_f1-score: 0.5444
# Epoch 18/30
# 276/276 [==============================] - 692s 3s/step - loss: 0.7682 - dice_coef: 0.5374 - iou_score: 0.3685 - f1-score: 0.5319 - val_loss: 0.7453 - val_dice_coef: 0.5531 - val_iou_score: 0.3792 - val_f1-score: 0.5422
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.2000000424450263e-05.
# Epoch 19/30
# 276/276 [==============================] - 655s 2s/step - loss: 0.7608 - dice_coef: 0.5413 - iou_score: 0.3727 - f1-score: 0.5357 - val_loss: 0.7384 - val_dice_coef: 0.5605 - val_iou_score: 0.3853 - val_f1-score: 0.5486
# Epoch 20/30
# 276/276 [==============================] - 649s 2s/step - loss: 0.7553 - dice_coef: 0.5431 - iou_score: 0.3742 - f1-score: 0.5380 - val_loss: 0.7395 - val_dice_coef: 0.5597 - val_iou_score: 0.3846 - val_f1-score: 0.5477
# Epoch 21/30
# 276/276 [==============================] - 648s 2s/step - loss: 0.7534 - dice_coef: 0.5447 - iou_score: 0.3766 - f1-score: 0.5405 - val_loss: 0.7398 - val_dice_coef: 0.5606 - val_iou_score: 0.3841 - val_f1-score: 0.5469
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 2.4000000848900527e-06.
# Epoch 22/30
# 276/276 [==============================] - 667s 2s/step - loss: 0.7549 - dice_coef: 0.5438 - iou_score: 0.3753 - f1-score: 0.5395 - val_loss: 0.7442 - val_dice_coef: 0.5605 - val_iou_score: 0.3827 - val_f1-score: 0.5443
# Epoch 23/30
# 276/276 [==============================] - 648s 2s/step - loss: 0.7531 - dice_coef: 0.5447 - iou_score: 0.3763 - f1-score: 0.5398 - val_loss: 0.7408 - val_dice_coef: 0.5609 - val_iou_score: 0.3841 - val_f1-score: 0.5464
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 4.800000169780105e-07.
# Epoch 24/30
# 276/276 [==============================] - 667s 2s/step - loss: 0.7602 - dice_coef: 0.5413 - iou_score: 0.3725 - f1-score: 0.5357 - val_loss: 0.7422 - val_dice_coef: 0.5613 - val_iou_score: 0.3840 - val_f1-score: 0.5463
# Restoring model weights from the end of the best epoch
# Epoch 00024: early stopping

# %% [markdown]
# ## Model loss graph

# %%
#@title
plot_metrics(history, metric_list=['loss', 'dice_coef', 'iou_score', 'f1-score'])
